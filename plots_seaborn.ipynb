# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(style="ticks", color_codes=True)
iris = sns.load_dataset("iris")
df=pd.DataFrame(iris)
print(type(iris))
iris.head()
import numpy as np
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
g=sns.pairplot(data=df,vars=['sepal_length','sepal_width'], palette="muted", hue='species', height=3,  markers=["+", "*", "o"], kind='box')
g = g.map_offdiag(plt.scatter,  s=35,alpha=0.5)

# %%
import matplotlib.pyplot as plt  #sets up plotting under plt
import seaborn as sns 			#sets up styles and gives us more plotting options
import pandas as pd

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set(style="ticks")

# Here we create a matplotlib axes object. The extra parameters we use
# "ci" to remove confidence interval
# "marker" to have a x as marker.
# "scatter_kws" to provide style info for the points.[s for size]
# "line_kws" to provide style info for the line.[lw for line width]

g = sns.regplot(x="tip", y="total_bill", data=tips, ci = True,
    scatter_kws={"color":"green","alpha":0.3,"s":9},
	line_kws={"color":"b","alpha":0.5,"lw":4},marker="+")

# remove the top and right line in graph
sns.despine()

# Set the size of the graph from here
g.figure.set_size_inches(12,8)
# Set the Title of the graph from here
g.axes.set_title('Total Bill vs. Tip', fontsize=34,color="r",alpha=0.5)
# Set the xlabel of the graph from here
g.set_xlabel("Tip",size = 67,color="r",alpha=0.5)
# Set the ylabel of the graph from here
g.set_ylabel("Total Bill",size = 67,color="r",alpha=0.5)
# Set the ticklabel size and color of the graph from here
g.tick_params(labelsize=14,labelcolor="black")

# %%
type(g)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
import seaborn as sns; 
#sns.set(color_codes=True)
tips = sns.load_dataset("tips")
ax = sns.regplot(x="total_bill", y="tip", data=tips, color='black', ci=68)

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
ax = sns.regplot(x="size", y="total_bill", data=tips)

# %%
sns.set_style("ticks")
sns.set_palette("bright")
sns.set_context("talk")
g = sns.regplot(x="size", y="total_bill", data=tips, x_jitter=.1, y_jitter=.5, order=1,\
                 scatter_kws={"s": 25, "color":'g'}, line_kws={'color':'g'})
sns.despine()
#g.axes.set_title("Regression Plot")
#g.set_xlabel("Tip",size = 25,color="r",alpha=0.5)
#g.set_ylabel("Total Bill",size = 25,color="r",alpha=0.5)
g.set(xlabel="Tip", ylabel="Total Bill", title="Regression Plot")
plt.xticks(rotation=45)
# Out:
# (array([0., 1., 2., 3., 4., 5., 6., 7.]),
#  <a list of 8 Text xticklabel objects>)

# %%
g=sns.relplot(data=tips, x="size", y="total_bill", kind="scatter", hue='smoker', col="sex", x_jitter=.5)
g.fig.suptitle("Scatterplot")
g.set(xlabel="Size", ylabel="Total Bill")
plt.show()

# %%
sns.set_style("dark")
sns.set_context("paper")
g = sns.scatterplot(x="total_bill", y="tip", hue="day", style="time" , size="size", data=tips)
g.set_ylabel("Tip",size = 30,color="r",alpha=0.9)
g.set_xlabel("Total Bill",size = 30,color="r",alpha=0.9)
g.axes.set_title("Scatter plot", size = 30)
#g.set(xlabel="Size", ylabel="Total Bill")
# Out:
# Text(0.5, 1.0, 'Scatter plot')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set()
g=sns.lineplot(x="total_bill", y="tip", data=tips, ci=95, hue="sex", color='r')
g.set_title("Lineplot", size=25, color='b')
g.set_xlabel("Total Bill", size=20, color='b')
g.set_ylabel("Tip", size=20, color='b')
# Out:
# Text(0, 0.5, 'Tip')

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
fmri = sns.load_dataset("fmri")
g=sns.lineplot(x="timepoint", y="signal", data=fmri, style='event', hue='region', ci=False)
g.set_title("Lineplot", size=25, color='b')
g.set_xlabel("Total Bill", size=20, color='b')
g.set_ylabel("Tip", size=20, color='b')
# Out:
# Text(0, 0.5, 'Tip')

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
import seaborn as sns
sns.set()
tips = sns.load_dataset("tips")
g= sns.boxplot(data=tips, x="total_bill")
g= sns.swarmplot(data=tips, x="total_bill", color='red', alpha=.5)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set_style("darkgrid")
g= sns.boxplot(data=tips, y="total_bill", x="day", hue="sex")
g= sns.stripplot(data=tips, y="total_bill", x="day", hue="sex", alpha=.5)
g.set_title("Boxplot", size=25, color='b')
g.set_xlabel("Day", size=20, color='b')
g.set_ylabel("Total Bill", size=20, color='b')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
sns.set_style("whitegrid")
g= sns.violinplot(data=tips, y="total_bill", x="day", hue="sex")
g= sns.stripplot(data=tips, y="total_bill", x="day", hue="sex", alpha=.5)
g.set_title("Violinplot", size=25, color='b')
g.set_xlabel("Day", size=20, color='b')
g.set_ylabel("Total Bill", size=20, color='b')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
sns.set_style("dark")
g= sns.boxenplot(data=tips, y="total_bill", x="day", hue="sex")
g= sns.stripplot(data=tips, y="total_bill", x="day", hue="sex", alpha=.5)
g.set_title("Boxenplot", size=25, color='b')
g.set_xlabel("Day", size=20, color='b')
g.set_ylabel("Total Bill", size=20, color='b')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
import seaborn as sns
sns.set(style="darkgrid")
tips = sns.load_dataset("tips")
g= sns.pointplot(x="time", y="total_bill", hue="sex",  data=tips, dodge=True)
g.set_title("Pointplot", size=25, color='b')
g.set_xlabel("Time", size=20, color='b')
g.set_ylabel("Total Bill", size=20, color='b')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import seaborn as sns
sns.set(style="darkgrid")
tips = sns.load_dataset("tips")
g= sns.barplot(x="time", y="total_bill", hue="sex",  data=tips, ci=False)
g.set_title("Barplot", size=25, color='b')
g.set_xlabel("Time", size=20, color='b')
g.set_ylabel("Total Bill", size=20, color='b')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
sns.set(style="darkgrid")
titanic = sns.load_dataset("titanic")
g= sns.countplot(x="class", data=titanic)
g.set_title("Countplot", size=25, color='b')
g.set_xlabel("Passenger Class", size=20, color='b')
g.set_ylabel("Count", size=20, color='b')
# Out:
# Text(0, 0.5, 'Count')
